# %%
# Load glottolangstatus dictionary from glottolog 
# where level=language
# select id, name, status
# Use languoid.csv file.  It codes status as string of <31 characters.

import csv
from collections import Counter
from collections import defaultdict

NOMATCH = "*****"
lang_status = defaultdict(lambda: NOMATCH)

filename = "data/languoid.csv"

with open(filename) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    count_level = Counter()
    count_status = Counter()
    count_lang_status = Counter()
    for row in csv_reader:
        lang_id = row[0]
        name = row[3]
        level = row[5]
        status = row[6]
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
        else:
            count_level[level] += 1
            count_status[status] += 1
        line_count += 1

        # Retain  the 'language' level.
        if level == 'language':
            count_lang_status[status] += 1
            # lang_status[lang_id] = (name, status)
            lang_status[lang_id] = status

            
    print(f'Processed {line_count} lines.')
    print("Level:", count_level)
    print("Status:", count_status)
    print("Language Status:", count_lang_status)
        
    # lang_status has language name and status indexed by glotto id.
# Out:
# Column names are id, family_id, parent_id, name, bookkeeping, level, status, latitude, longitude, iso639P3code, description, markup_description, child_family_count, child_language_count, child_dialect_count, country_ids
# Processed 24338 lines.
# Level: Counter({'dialect': 11467, 'language': 8496, 'family': 4374})
# Status: Counter({'safe': 19301, 'definitely endangered': 1800, 'vulnerable': 1447, 'extinct': 906, 'critically endangered': 460, 'severely endangered': 423})
# Language Status: Counter({'safe': 3554, 'definitely endangered': 1791, 'vulnerable': 1433, 'extinct': 848, 'critically endangered': 451, 'severely endangered': 419})

# %%
# Service function to print column names
def print_parameters(col_names):
    for i, name in enumerate(col_names):
        print(i, name)
        
# Load WALS database from .csv file.

WALS_info = []

infilename = "data/language.csv"
outfilename = "data/wals_language_withstatus.orig.csv"
outfilenamematch = "data/wals_language_withstatus.csv"

with open(infilename) as csv_file, \
open(outfilename, mode='w') as csv_outfile, \
open(outfilenamematch, mode='w') as csv_outfilematch:
    csv_reader = csv.reader(csv_file, delimiter=',')
    csv_writer = csv.writer(csv_outfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writermatch = csv.writer(csv_outfilematch, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)


    line_count = 0
    count_family = Counter()
    count_macroarea = Counter()
    glottomatch_count = 0
    glottonomatch_count = 0
    glottocodenone_count = 0
    
    for row in csv_reader:
        wals_code = row[0]
        glotto_code = row[2] if len(row[2]) > 0 else None
        family = row[7]
        macroarea = row[8]
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            #print_parameters(row)
            WALS_names = row
            WALS_names.insert(10, "Status from Glotto")
            print_parameters(WALS_names)
            csv_writer.writerow(WALS_names)
            csv_writermatch.writerow(WALS_names)

        else:
            count_family[family] += 1
            count_macroarea[macroarea] += 1
            WALS_row = row
            status = lang_status[glotto_code] if glotto_code != None else None
            if status == NOMATCH:
                glottonomatch_count += 1
            elif status == None:
                glottocodenone_count += 1
            else:
                glottomatch_count += 1
                    
            WALS_row.insert(10, status)
            csv_writer.writerow(WALS_row)
            if status != NOMATCH and status != None:
                csv_writermatch.writerow(WALS_row)
            #if line_count < 20:
            #    print(WALS_row[:15])

            
        line_count += 1
        
            
    print(f'Processed {line_count} lines.')
    #print("Family:", count_family)
    print("Macroarea:", count_macroarea)
    print("Glotto match:", glottomatch_count, "nomatch:", 
          glottonomatch_count, "glottonone:", glottocodenone_count)
# Out:
# 0 wals_code
# 1 iso_code
# 2 glottocode
# 3 Name
# 4 latitude
# 5 longitude
# 6 genus
# 7 family
# 8 macroarea
# 9 countrycodes
# 10 Status from Glotto
# 11 1A Consonant Inventories
# 12 2A Vowel Quality Inventories
# 13 3A Consonant-Vowel Ratio
# 14 4A Voicing in Plosives and Fricatives
# 15 5A Voicing and Gaps in Plosive Systems
# 16 6A Uvular Consonants
# 17 7A Glottalized Consonants
# 18 8A Lateral Consonants
# 19 9A The Velar Nasal
# 20 10A Vowel Nasalization
# 21 11A Front Rounded Vowels
# 22 12A Syllable Structure
# 23 13A Tone
# 24 14A Fixed Stress Locations
# 25 15A Weight-Sensitive Stress
# 26 16A Weight Factors in Weight-Sensitive Stress Systems
# 27 17A Rhythm Types
# 28 18A Absence of Common Consonants
# 29 19A Presence of Uncommon Consonants
# 30 20A Fusion of Selected Inflectional Formatives
# 31 21A Exponence of Selected Inflectional Formatives
# 32 22A Inflectional Synthesis of the Verb
# 33 23A Locus of Marking in the Clause
# 34 24A Locus of Marking in Possessive Noun Phrases
# 35 25A Locus of Marking: Whole-language Typology
# 36 26A Prefixing vs. Suffixing in Inflectional Morphology
# 37 27A Reduplication
# 38 28A Case Syncretism
# 39 29A Syncretism in Verbal Person/Number Marking
# 40 30A Number of Genders
# 41 31A Sex-based and Non-sex-based Gender Systems
# 42 32A Systems of Gender Assignment
# 43 33A Coding of Nominal Plurality
# 44 34A Occurrence of Nominal Plurality
# 45 35A Plurality in Independent Personal Pronouns
# 46 36A The Associative Plural
# 47 37A Definite Articles
# 48 38A Indefinite Articles
# 49 39A Inclusive/Exclusive Distinction in Independent Pronouns
# 50 40A Inclusive/Exclusive Distinction in Verbal Inflection
# 51 41A Distance Contrasts in Demonstratives
# 52 42A Pronominal and Adnominal Demonstratives
# 53 43A Third Person Pronouns and Demonstratives
# 54 44A Gender Distinctions in Independent Personal Pronouns
# 55 45A Politeness Distinctions in Pronouns
# 56 46A Indefinite Pronouns
# 57 47A Intensifiers and Reflexive Pronouns
# 58 48A Person Marking on Adpositions
# 59 49A Number of Cases
# 60 50A Asymmetrical Case-Marking
# 61 51A Position of Case Affixes
# 62 52A Comitatives and Instrumentals
# 63 53A Ordinal Numerals
# 64 54A Distributive Numerals
# 65 55A Numeral Classifiers
# 66 56A Conjunctions and Universal Quantifiers
# 67 57A Position of Pronominal Possessive Affixes
# 68 58A Obligatory Possessive Inflection
# 69 59A Possessive Classification
# 70 60A Genitives, Adjectives and Relative Clauses
# 71 61A Adjectives without Nouns
# 72 62A Action Nominal Constructions
# 73 63A Noun Phrase Conjunction
# 74 64A Nominal and Verbal Conjunction
# 75 65A Perfective/Imperfective Aspect
# 76 66A The Past Tense
# 77 67A The Future Tense
# 78 68A The Perfect
# 79 69A Position of Tense-Aspect Affixes
# 80 70A The Morphological Imperative
# 81 71A The Prohibitive
# 82 72A Imperative-Hortative Systems
# 83 73A The Optative
# 84 74A Situational Possibility
# 85 75A Epistemic Possibility
# 86 76A Overlap between Situational and Epistemic Modal Marking
# 87 77A Semantic Distinctions of Evidentiality
# 88 78A Coding of Evidentiality
# 89 79A Suppletion According to Tense and Aspect
# 90 80A Verbal Number and Suppletion
# 91 81A Order of Subject, Object and Verb
# 92 82A Order of Subject and Verb
# 93 83A Order of Object and Verb
# 94 84A Order of Object, Oblique, and Verb
# 95 85A Order of Adposition and Noun Phrase
# 96 86A Order of Genitive and Noun
# 97 87A Order of Adjective and Noun
# 98 88A Order of Demonstrative and Noun
# 99 89A Order of Numeral and Noun
# 100 90A Order of Relative Clause and Noun
# 101 91A Order of Degree Word and Adjective
# 102 92A Position of Polar Question Particles
# 103 93A Position of Interrogative Phrases in Content Questions
# 104 94A Order of Adverbial Subordinator and Clause
# 105 95A Relationship between the Order of Object and Verb and the Order of Adposition and Noun Phrase
# 106 96A Relationship between the Order of Object and Verb and the Order of Relative Clause and Noun
# 107 97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun
# 108 98A Alignment of Case Marking of Full Noun Phrases
# 109 99A Alignment of Case Marking of Pronouns
# 110 100A Alignment of Verbal Person Marking
# 111 101A Expression of Pronominal Subjects
# 112 102A Verbal Person Marking
# 113 103A Third Person Zero of Verbal Person Marking
# 114 104A Order of Person Markers on the Verb
# 115 105A Ditransitive Constructions: The Verb 'Give'
# 116 106A Reciprocal Constructions
# 117 107A Passive Constructions
# 118 108A Antipassive Constructions
# 119 109A Applicative Constructions
# 120 110A Periphrastic Causative Constructions
# 121 111A Nonperiphrastic Causative Constructions
# 122 112A Negative Morphemes
# 123 113A Symmetric and Asymmetric Standard Negation
# 124 114A Subtypes of Asymmetric Standard Negation
# 125 115A Negative Indefinite Pronouns and Predicate Negation
# 126 116A Polar Questions
# 127 117A Predicative Possession
# 128 118A Predicative Adjectives
# 129 119A Nominal and Locational Predication
# 130 120A Zero Copula for Predicate Nominals
# 131 121A Comparative Constructions
# 132 122A Relativization on Subjects
# 133 123A Relativization on Obliques
# 134 124A 'Want' Complement Subjects
# 135 125A Purpose Clauses
# 136 126A 'When' Clauses
# 137 127A Reason Clauses
# 138 128A Utterance Complement Clauses
# 139 129A Hand and Arm
# 140 130A Finger and Hand
# 141 131A Numeral Bases
# 142 132A Number of Non-Derived Basic Colour Categories
# 143 133A Number of Basic Colour Categories
# 144 134A Green and Blue
# 145 135A Red and Yellow
# 146 136A M-T Pronouns
# 147 137A N-M Pronouns
# 148 138A Tea
# 149 139A Irregular Negatives in Sign Languages
# 150 140A Question Particles in Sign Languages
# 151 141A Writing Systems
# 152 142A Para-Linguistic Usages of Clicks
# 153 143F Postverbal Negative Morphemes
# 154 90B Prenominal relative clauses
# 155 144Y The Position of Negative Morphemes in Object-Initial Languages
# 156 90C Postnominal relative clauses
# 157 144P NegSOV Order
# 158 144J SVNegO Order
# 159 144N Obligatory Double Negation in SOV languages
# 160 144S SOVNeg Order
# 161 144X Verb-Initial with Clause-Final Negative
# 162 144A Position of Negative Word With Respect to Subject, Object, and Verb
# 163 90G Double-headed relative clauses
# 164 90E Correlative relative clauses
# 165 144V Verb-Initial with Preverbal Negative
# 166 144I SNegVO Order
# 167 144R SONegV Order
# 168 143B Obligatory Double Negation
# 169 144M Multiple Negative Constructions in SOV Languages
# 170 144U Double negation in verb-initial languages
# 171 144G Optional Double Negation in SVO languages
# 172 144K SVONeg Order
# 173 144B Position of negative words relative to beginning and end of clause and with respect to adjacency to verb
# 174 144F Obligatory Double Negation in SVO languages
# 175 90D Internally-headed relative clauses
# 176 144E Multiple Negative Constructions in SVO Languages
# 177 144D The Position of Negative Morphemes in SVO Languages
# 178 81B Languages with two Dominant Orders of Subject, Object, and Verb
# 179 143E Preverbal Negative Morphemes
# 180 143C Optional Double Negation
# 181 90F Adjoined relative clauses
# 182 143A Order of Negative Morpheme and Verb
# 183 144W Verb-Initial with Negative that is Immediately Postverbal or between Subject and Object
# 184 144O Optional Double Negation in SOV languages
# 185 144Q SNegOV Order
# 186 144L The Position of Negative Morphemes in SOV Languages
# 187 144H NegSVO Order
# 188 144C Languages with different word order in negative clauses
# 189 144T The Position of Negative Morphemes in Verb-Initial Languages
# 190 143G Minor morphological means of signaling negation
# 191 143D Optional Triple Negation
# 192 39B Inclusive/Exclusive Forms in Pama-Nyungan
# 193 137B M in Second Person Singular
# 194 136B M in First Person Singular
# 195 109B Other Roles of Applied Objects
# 196 10B Nasal Vowels in West Africa
# 197 25B Zero Marking of A and P Arguments
# 198 21B Exponence of Tense-Aspect-Mood Inflection
# 199 108B Productivity of the Antipassive Construction
# 200 130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'
# 201 58B Number of Possessive Nouns
# 202 79B Suppletion in Imperatives and Hortatives
# Processed 2680 lines.
# Macroarea: Counter({'Eurasia': 660, 'Africa': 607, 'Papunesia': 558, 'North America': 398, 'South America': 257, 'Australia': 177, '': 22})
# Glotto match: 2596 nomatch: 64 glottonone: 19
